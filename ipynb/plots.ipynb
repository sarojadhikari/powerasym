# %%
from powerasym.padists import PowerAsymmetryDistribution
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
MAPS = 10000

pad = PowerAsymmetryDistribution(datafolder="../data", NMAPS = MAPS)
pad.set_fgnl([250, 500])
pad.read_data()

# %%
pad.plot_A()
plt.show()

# %%
from powerasym.posterior import PosteriorfNL

# %%
pf = PosteriorfNL()
pf.plot_combined_posteriors_withA0(A0list=[0.0, 0.02, 0.04, 0.04], Nlist=[10, 50, 50, 100])
plt.legend(loc=0, fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.ylim(2E-5, 0.02)
plt.show()

# %%
pf.plot_pvalues()
plt.legend(loc=0, fontsize=14)
